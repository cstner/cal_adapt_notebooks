# %% [markdown]
# # This notebook demonstrates how to do the first steps of any Analytics Engine (AE) activity: selecting data to import, and generating a dataset to work with. Then it demonstrates how to export that data.
# ## It starts with some imports

# %%
import xarray as xr
import panel as pn

pn.extension()

# %%
# !pip install --upgrade git+https://github.com/cal-adapt/climakitae.git

# !pip install git+https://github.com/cal-adapt/climakitae.git@0.0.1
# %pip install https://github.com/cal-adapt/climakitae/archive/main.zip
# Out:
# Collecting git+https://github.com/cal-adapt/climakitae.git
#   Cloning https://github.com/cal-adapt/climakitae.git to /tmp/pip-req-build-a39kjm3x
#   Running command git clone -q https://github.com/cal-adapt/climakitae.git /tmp/pip-req-build-a39kjm3x
#   Resolved https://github.com/cal-adapt/climakitae.git to commit cc999383cc839f12debd6ca3921868098ee09f73
# Requirement already satisfied: cartopy in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (0.18.0)
# Requirement already satisfied: geopandas in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (0.10.2)
# Requirement already satisfied: geoviews in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (1.9.5)
# Requirement already satisfied: holoviews in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (1.14.8)
# Requirement already satisfied: hvplot in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (0.7.3)
# Collecting intake-xarray
#   Downloading intake_xarray-0.6.0-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: lmoments3 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (1.0.1)
# Requirement already satisfied: matplotlib in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (3.1.3)
# Requirement already satisfied: numpy in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (1.21.2)
# Requirement already satisfied: pandas in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (1.4.1)
# Requirement already satisfied: panel in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (0.12.7)
# Requirement already satisfied: param in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (1.12.1)
# Requirement already satisfied: regionmask in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (0.9.0)
# Collecting s3fs
#   Downloading s3fs-2022.3.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: scipy in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (1.7.3)
# Requirement already satisfied: shapely in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (1.7.1)
# Requirement already satisfied: xarray in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from climakitae==0.0.1) (2022.3.0)
# Requirement already satisfied: setuptools>=0.7.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from cartopy->climakitae==0.0.1) (58.0.4)
# Requirement already satisfied: six>=1.3.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from cartopy->climakitae==0.0.1) (1.16.0)
# Requirement already satisfied: pyshp>=1.1.4 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from cartopy->climakitae==0.0.1) (2.1.3)
# Requirement already satisfied: pyproj>=2.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from geopandas->climakitae==0.0.1) (3.3.0)
# Requirement already satisfied: fiona>=1.8 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from geopandas->climakitae==0.0.1) (1.8.21)
# Requirement already satisfied: click>=4.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from fiona>=1.8->geopandas->climakitae==0.0.1) (8.1.2)
# Requirement already satisfied: certifi in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from fiona>=1.8->geopandas->climakitae==0.0.1) (2021.10.8)
# Requirement already satisfied: click-plugins>=1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from fiona>=1.8->geopandas->climakitae==0.0.1) (1.1.1)
# Requirement already satisfied: attrs>=17 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from fiona>=1.8->geopandas->climakitae==0.0.1) (21.2.0)
# Requirement already satisfied: munch in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from fiona>=1.8->geopandas->climakitae==0.0.1) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from fiona>=1.8->geopandas->climakitae==0.0.1) (0.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from pandas->climakitae==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from pandas->climakitae==0.0.1) (2021.3)
# Requirement already satisfied: packaging in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from geoviews->climakitae==0.0.1) (21.3)
# Requirement already satisfied: bokeh<2.5,>=2.4.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from geoviews->climakitae==0.0.1) (2.4.2)
# Requirement already satisfied: Jinja2>=2.9 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae==0.0.1) (3.0.3)
# Requirement already satisfied: PyYAML>=3.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae==0.0.1) (6.0)
# Requirement already satisfied: tornado>=5.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae==0.0.1) (6.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae==0.0.1) (3.10.0.2)
# Requirement already satisfied: pillow>=7.1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from bokeh<2.5,>=2.4.0->geoviews->climakitae==0.0.1) (9.1.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from holoviews->climakitae==0.0.1) (2.2.0)
# Requirement already satisfied: colorcet in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from holoviews->climakitae==0.0.1) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh<2.5,>=2.4.0->geoviews->climakitae==0.0.1) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from packaging->geoviews->climakitae==0.0.1) (3.0.6)
# Requirement already satisfied: requests in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from panel->climakitae==0.0.1) (2.27.1)
# Requirement already satisfied: tqdm>=4.48.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from panel->climakitae==0.0.1) (4.64.0)
# Requirement already satisfied: markdown in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from panel->climakitae==0.0.1) (3.3.6)
# Requirement already satisfied: bleach in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from panel->climakitae==0.0.1) (4.1.0)
# Requirement already satisfied: pyct>=0.4.4 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from panel->climakitae==0.0.1) (0.4.8)
# Requirement already satisfied: webencodings in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from bleach->panel->climakitae==0.0.1) (0.5.1)
# Requirement already satisfied: intake>=0.5.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from intake-xarray->climakitae==0.0.1) (0.6.5)
# Requirement already satisfied: dask>=2.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from intake-xarray->climakitae==0.0.1) (2022.4.0)
# Requirement already satisfied: fsspec>0.8.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from intake-xarray->climakitae==0.0.1) (2022.3.0)
# Requirement already satisfied: netcdf4 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from intake-xarray->climakitae==0.0.1) (1.5.8)
# Requirement already satisfied: zarr in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from intake-xarray->climakitae==0.0.1) (2.11.3)
# Collecting msgpack
#   Downloading msgpack-1.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      |████████████████████████████████| 322 kB 85.0 MB/s eta 0:00:01
# Requirement already satisfied: partd>=0.3.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from dask>=2.2->intake-xarray->climakitae==0.0.1) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from dask>=2.2->intake-xarray->climakitae==0.0.1) (0.11.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from dask>=2.2->intake-xarray->climakitae==0.0.1) (2.0.0)
# Requirement already satisfied: appdirs in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from intake>=0.5.2->intake-xarray->climakitae==0.0.1) (1.4.4)
# Requirement already satisfied: entrypoints in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from intake>=0.5.2->intake-xarray->climakitae==0.0.1) (0.3)
# Requirement already satisfied: locket in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from partd>=0.3.10->dask>=2.2->intake-xarray->climakitae==0.0.1) (0.2.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from markdown->panel->climakitae==0.0.1) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown->panel->climakitae==0.0.1) (3.6.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from matplotlib->climakitae==0.0.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from matplotlib->climakitae==0.0.1) (0.11.0)
# Requirement already satisfied: cftime in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from netcdf4->intake-xarray->climakitae==0.0.1) (1.6.0)
# Requirement already satisfied: rasterio>=1.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from regionmask->climakitae==0.0.1) (1.2.10)
# Requirement already satisfied: pooch>=1.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from regionmask->climakitae==0.0.1) (1.6.0)
# Requirement already satisfied: affine in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from rasterio>=1.1->regionmask->climakitae==0.0.1) (2.3.1)
# Requirement already satisfied: snuggs>=1.4.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from rasterio>=1.1->regionmask->climakitae==0.0.1) (1.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from requests->panel->climakitae==0.0.1) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from requests->panel->climakitae==0.0.1) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from requests->panel->climakitae==0.0.1) (2.0.12)
# Collecting aiobotocore~=2.2.0
#   Downloading aiobotocore-2.2.0.tar.gz (59 kB)
#      |████████████████████████████████| 59 kB 13.3 MB/s eta 0:00:01
# Requirement already satisfied: aiohttp<=4 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from s3fs->climakitae==0.0.1) (3.8.1)
# Collecting botocore<1.24.22,>=1.24.21
#   Downloading botocore-1.24.21-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 39.8 MB/s eta 0:00:01
# Collecting wrapt>=1.10.10
#   Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
#      |████████████████████████████████| 81 kB 14.1 MB/s eta 0:00:01
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.10.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from aiohttp<=4->s3fs->climakitae==0.0.1) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from aiohttp<=4->s3fs->climakitae==0.0.1) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from aiohttp<=4->s3fs->climakitae==0.0.1) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from aiohttp<=4->s3fs->climakitae==0.0.1) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from aiohttp<=4->s3fs->climakitae==0.0.1) (1.3.0)
# Collecting typing-extensions>=3.10.0
#   Downloading typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from botocore<1.24.22,>=1.24.21->aiobotocore~=2.2.0->s3fs->climakitae==0.0.1) (1.0.0)
# Requirement already satisfied: fasteners in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from zarr->intake-xarray->climakitae==0.0.1) (0.17.3)
# Requirement already satisfied: numcodecs>=0.6.4 in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from zarr->intake-xarray->climakitae==0.0.1) (0.9.1)
# Requirement already satisfied: asciitree in /home/studio-lab-user/.conda/envs/default/lib/python3.8/site-packages (from zarr->intake-xarray->climakitae==0.0.1) (0.3.3)
# Building wheels for collected packages: aiobotocore
#   Building wheel for aiobotocore (setup.py) ... done
#   Created wheel for aiobotocore: filename=aiobotocore-2.2.0-py3-none-any.whl size=57108 sha256=4975e724866b90db00a0f7a1f243c9b9fe1e19b995812cb727869ac6f2d4f840
#   Stored in directory: /home/studio-lab-user/.cache/pip/wheels/db/12/8e/d44b7a03257689abfdaa25a0df327834efdcab15f7cc2bbba9
# Successfully built aiobotocore
# Installing collected packages: typing-extensions, wrapt, botocore, aioitertools, msgpack, aiobotocore, s3fs, intake-xarray
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.24.22
#     Uninstalling botocore-1.24.22:
#       Successfully uninstalled botocore-1.24.22
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.21.22 requires botocore<1.25.0,>=1.24.22, but you have botocore 1.24.21 which is incompatible.
# Successfully installed aiobotocore-2.2.0 aioitertools-0.10.0 botocore-1.24.21 intake-xarray-0.6.0 msgpack-1.0.3 s3fs-2022.3.0 typing-extensions-4.2.0 wrapt-1.14.1

# %%
import climakitae as ck

# %% [markdown]
# ## First step using the *climakitae* (the python 'climate kit' library containing our AE tools): load a new application

# %%
app = ck.Application()

# %% [markdown]
# ## Now we can call 'select' to display an interface from which to select the data to examine.
# ### This version only offers the dynamically-downscaled data produced at hourly intervals. As a result, if you select 'daily' for 'Timescale' it will result in a daily average of the hourly data.
#
# Future projections are so far available for three different greenhouse gas emissions scenarios (Shared Socioeconomic Pathways or SSPs) through 2100 from one General Circulation Model (GCM)  simulation, and for one SSP for another 3 GCMs. “Historical Climate” includes data from 1980-2014 simulated from GCMs used to produce the SSPs, which can be appended to a SSP time series using the option “Append historical.” Because this historical data is obtained through simulations, it represents average weather during the historical period but will not accurately capture historical phasing of variability in these variables.
#
# “Historical Reconstruction” provides a reference downscaled reanalysis data based on atmospheric models fit to satellite and station observations, and as a result will reflect observed historical weather time series.

# %%
app.select()
# Out:
# Column
#     [0] Row
#         [0] Column
#             [0] Select(name='Timescale', options=OrderedDict([('hourly', ...]), value='monthly')
#             [1] Select(name='Variable', options=OrderedDict([('Accumulated...]), value='T2')
#             [2] RadioButtonGroup(name='Resolution', options=OrderedDict([('9 km', ...]), value='45 km')
#         [1] Column
#             [0] CheckBoxGroup(name='Scenario', options=OrderedDict([('Historical ...]))
#             [1] Checkbox(name='Append historical')
#             [2] Checkbox(name='Area average')
#     [1] Row
#         [0] Column(margin=5, name='LocSelectorArea', width=300)
#             [0] StaticText(value='<b>LocSelectorArea</b>')
#             [1] Select(name='Area subset', options=OrderedDict([('none', ...]), value='none')
#             [2] RangeSlider(end=67, name='Latitude', start=10, value=(32.5, 42), value_end=42, value_start=32.5)
#             [3] RangeSlider(end=-84.18701, name='Longitude', start=-156.82317, value=(-125.5, -114), value_end=-114, value_start=-125.5)
#             [4] Select(name='Cached area', options=OrderedDict([('CA', ...]), value='CA')
#         [1] ParamMethod(method)

# %% [markdown]
# ## Finally, call app.retrieve() to load the subset/combo of data specified

# %%
data_to_use = app.retrieve()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1726/3536534344.py in <module>
# ----> 1 data_to_use = app.retrieve()
#
# ~/.conda/envs/default/lib/python3.8/site-packages/climakitae/core.py in retrieve(self)
#      33         """
#      34         # to do: insert additional 'hang in there' statement if it's taking a while
# ---> 35         return _read_from_catalog(self.selections, self.location)
#      36
#      37     # === Export ======================================
#
# ~/.conda/envs/default/lib/python3.8/site-packages/climakitae/data_loaders.py in _read_from_catalog(selections, location)
#     105     stored in 'selections' and 'location').
#     106     """
# --> 107     assert not selections.scenario[0] is None, "Please select at least one scenario."
#     108
#     109     if location.area_subset == "lat/lon":
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ### You can preview the data in the retrieved, aggregated dataset when this is complete. It may take several minutes.

# %%
data_to_use

# %% [markdown]
# ## Now you can examine the data, and do anything else you like with it:

# %%
# [insert your own code here]

# %% [markdown]
# #### You can load up another variable or resolution by modifying your selections and calling: next_data = app.retrieve()
# ##### If you do this a lot, and things are starting to get slow, you might want to try: data_to_use.close()

# %% [markdown]
# # Finally, export the data:
#
# Use the below code to export a dataset as a NetCDF, GeoTIFF, or CSV file. Provide the name of the dataset in the environment to export as well as a character string containing the file name in quotations. If the dataset contains multiple variables, provide an argument specifying which variable to export (e.g. variable=”T2”). If you would like to save data as a GeoTIFF or CSV file and the dataset contains scenarios or simulations, additionally provide arguments specifying the scenario (scenario=”historical”) and the simulation (simulation=”cesm2”).

# %%
app.export_as()

# %%
app.export_dataset(data_to_use,'my_filename')
